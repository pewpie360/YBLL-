# %% [markdown]
# # Advance GenAI Workshop
# author: King Matthew Ochoa
#
# ---
# ## Setup Preparation
#
# Before we can do anything, we should have the necessary python libraries. The cell below installs them using pip package manager.

# %% [markdown]
# ## <center>`Lumikas Now!Tech`
# ### <center>`Group Members`
# <center> Hayron Tanate
# <center> Jhibsam Palmes
# <center> Erika Orquia
# <center> Aisha Go
# <center> Christian Jay Baguio

# %%
# !pip install tiktoken
# Out:
# Collecting tiktoken
#   Downloading tiktoken-0.9.0-cp311-cp311-win_amd64.whl.metadata (6.8 kB)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\atara\anaconda3\lib\site-packages (from tiktoken) (2024.7.24)
# Requirement already satisfied: requests>=2.26.0 in c:\users\atara\anaconda3\lib\site-packages (from tiktoken) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\atara\anaconda3\lib\site-packages (from requests>=2.26.0->tiktoken) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\atara\anaconda3\lib\site-packages (from requests>=2.26.0->tiktoken) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\atara\anaconda3\lib\site-packages (from requests>=2.26.0->tiktoken) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\atara\anaconda3\lib\site-packages (from requests>=2.26.0->tiktoken) (2024.7.4)
# Downloading tiktoken-0.9.0-cp311-cp311-win_amd64.whl (893 kB)
#    ---------------------------------------- 0.0/893.9 kB ? eta -:--:--
#    --------------------------------------- 893.9/893.9 kB 10.0 MB/s eta 0:00:00
# Installing collected packages: tiktoken
# Successfully installed tiktoken-0.9.0

# %%
import tiktoken
def get_tokens(txt, model):
    encoding = tiktoken.encoding_for_model(model)
    tokens = encoding.encode(txt)
    return tokens

tokens = get_tokens("The irreplaceable vase has been broken and now irreperable.", "gpt-4")
print(tokens)
# Out:
# [791, 6348, 8319, 481, 93484, 706, 1027, 11102, 323, 1457, 25912, 716, 481, 13]

# %% [markdown]
# # Labwork
# ### We will need to install a certain version of langchain, langchain-groq.

# %%
# !pip install langchain-groq
#!pip install pandas
# Out:
# Requirement already satisfied: langchain-groq in c:\users\atara\anaconda3\lib\site-packages (0.3.2)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.49 in c:\users\atara\anaconda3\lib\site-packages (from langchain-groq) (0.3.51)
# Requirement already satisfied: groq<1,>=0.4.1 in c:\users\atara\anaconda3\lib\site-packages (from langchain-groq) (0.22.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\atara\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\atara\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\atara\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\atara\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (2.5.3)
# Requirement already satisfied: sniffio in c:\users\atara\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (1.3.0)
# Requirement already satisfied: typing-extensions<5,>=4.10 in c:\users\atara\anaconda3\lib\site-packages (from groq<1,>=0.4.1->langchain-groq) (4.11.0)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\atara\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.49->langchain-groq) (0.3.30)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\atara\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.49->langchain-groq) (8.2.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\atara\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.49->langchain-groq) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\atara\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.49->langchain-groq) (6.0.1)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\atara\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.49->langchain-groq) (24.1)
# Requirement already satisfied: idna>=2.8 in c:\users\atara\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->groq<1,>=0.4.1->langchain-groq) (3.7)
# Requirement already satisfied: certifi in c:\users\atara\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in c:\users\atara\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\atara\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\atara\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.49->langchain-groq) (2.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\atara\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.49->langchain-groq) (3.10.16)
# Requirement already satisfied: requests<3,>=2 in c:\users\atara\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.49->langchain-groq) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\atara\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.49->langchain-groq) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\atara\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.49->langchain-groq) (0.23.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\atara\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain-groq) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in c:\users\atara\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain-groq) (2.14.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\atara\anaconda3\lib\site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.49->langchain-groq) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\atara\anaconda3\lib\site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.49->langchain-groq) (1.26.20)

# %% [markdown]
# ### Saving the groq key created:

# %%
import os
your_api_key = ""
os.environ['GROQ_API_KEY'] = your_api_key

# %% [markdown]
# ### Importing the modules

# %%
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import JsonOutputParser
import json

# %%
# Initialize Groq LLM
llm = ChatGroq(
    model_name="llama-3.3-70b-versatile",
    temperature=0.7
)

#setup the prompt
prompt = ChatPromptTemplate.from_messages([
    ("system", """You are a translator from english to german. :D"""),
    ("user", "{input}")
])

prompt_num2 = ChatPromptTemplate.from_messages([
    ("system", """You are a translator from english to tagalog. :D"""),
    ("user", "{input}")
])

prompt_num3 = ChatPromptTemplate.from_messages([
    ("system", """You are a translator from english to romanji. :D"""),
    ("user", "{input}")
])

#define the chain
chain = prompt | llm #German
chain2 = prompt_num2 | llm # Tagalog
chain3 = prompt_num3 | llm # Romanji

#call the LLM
sentence = "Hello welcome to YBLL Workshop!"
result = chain.invoke({"input": sentence})
result.content
# Out:
# 'Hallo, herzlich willkommen im YBLL-Workshop!'

# %%
#sample queries
sentence_num2 = "Hello, My Name is Christian Jay Baguio"
sentence_num3 = "Hello, My Name is Hayron Tanate"
sentence_num4 = "Hello, My Name is Jhibsam Palmes"
sentence_num5 = "Hello, My Name is Erika Orquia"
sentence_num6 = "Hello, My Name is Aisha Go"

def Chain(sentence1, sentence2, sentence3, sentence4, sentence5):
    result_num1 = chain.invoke({"input": sentence1})
    result_num2 = chain2.invoke({"input": sentence2})
    result_num3 = chain2.invoke({"input": sentence3})
    result_num4 = chain3.invoke({"input": sentence4})
    result_num5 = chain3.invoke({"input": sentence5})

    display(result_num1.content)
    display(result_num2.content)
    display(result_num3.content)
    display(result_num4.content)
    display(result_num5.content)
Chain(sentence_num2, sentence_num3, sentence_num4, sentence_num5, sentence_num6)
# Out:
# 'Hallo, ich heiße Christian Jay Baguio.\n\n(Translation: Hello, my name is Christian Jay Baguio)\n\nWillkommen! Wie kann ich Ihnen helfen? (Welcome! How can I help you?)'
# 'Kumusta, Ang pangalan ko ay Hayron Tanate. (Hello, My name is Hayron Tanate.)\n\nOr in a more natural Tagalog translation:\nKumusta, Ako si Hayron Tanate. \n\n(Kumusta is a casual way of saying hello, and "Ako si" is a more natural way to introduce oneself in Tagalog.)'
# 'Kumusta, Ang pangalan ko ay Jhibsam Palmes. (Hello, My name is Jhibsam Palmes.)\n\nOr in a more natural Tagalog translation:\nKumusta, Ako si Jhibsam Palmes.'
# 'Konnichiwa, Watashi wa Erika Orquia desu.\n\n(Note: Konnichiwa is a formal greeting, and "Watashi wa" is a polite way to say "my name is" in Japanese. "Desu" is a polite verb ending to indicate a statement.)\n\nHere\'s the breakdown:\n- Hello: Konnichiwa \n- My Name is: Watashi wa\n- Erika: Erika (remains the same, as it\'s a proper noun)\n- Orquia: Orukia (Romanji translation of the surname)'
# "Konnichiwa, Watashi wa Aisha Go desu. \n\n(Breakdown: \nKonnichiwa - Hello\nWatashi wa - My name is\nAisha Go - remains the same, as it's a proper noun\ndesu - a polite suffix to indicate the sentence is a statement)"

# %%
# Initialize Groq LLM
llm = ChatGroq(
    model_name="llama-3.3-70b-versatile",
    temperature=0.7
)

# Define the expected JSON structure
parser = JsonOutputParser(pydantic_object={
    "type": "object",
    "properties": {
        "name": {"type": "string"},
        "price": {"type": "number"},
        "features": {
            "type": "array",
            "items": {"type": "string"}
        }
    }
})

# Create a simple prompt
prompt = ChatPromptTemplate.from_messages([
    ("system", """Extract product details into JSON with this structure:
        {{
            "name": "product name here",
            "price": number_here_without_currency_symbol,
            "features": ["feature1", "feature2", "feature3"]
        }}"""),
    ("user", "{input}")
])

# Create the chain that guarantees JSON output
chain = prompt | llm | parser

def parse_product(description: str) -> dict:
    result = chain.invoke({"input": description})
    print(json.dumps(result, indent=2))

        
# Example usage
description = """The Kees Van Der Westen Speedster is a high-end, single-group espresso machine known for its precision, performance, 
and industrial design. Handcrafted in the Netherlands, it features dual boilers for brewing and steaming, PID temperature control for 
consistency, and a unique pre-infusion system to enhance flavor extraction. Designed for enthusiasts and professionals, it offers 
customizable aesthetics, exceptional thermal stability, and intuitive operation via a lever system. The pricing is approximatelyt $14,499 
depending on the retailer and customization options."""

parse_product(description)
# Out:
# {
#   "name": "Kees Van Der Westen Speedster",
#   "price": 14499,
#   "features": [
#     "Dual boilers for brewing and steaming",
#     "PID temperature control",
#     "Pre-infusion system",
#     "Customizable aesthetics",
#     "Exceptional thermal stability",
#     "Intuitive operation via a lever system"
#   ]
# }

# %% [markdown]
# ---

# %% [markdown]
# ## It's your turn!
# # Activity 1
# 🧠  Prompt Engineering Exercise: Sentiment Analyzer
# ### 📦 Scenario
# #### Given the dataframe below, add the column value for the sentiment of the expression.
#
# ### 🎯 Objective
# #### Craft a high-quality prompt that fills out the empty `sentiment` column of the pandas dataframe.
#
# *hint: create a function and loop over.

# %%
#imports
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from langchain_core.output_parsers import StrOutputParser
import pandas as pd
from textblob import TextBlob

# %%
sentiment_df = pd.DataFrame([
    "This is amazing!",
    "I can't stop smiling!",
    "I'm so thrilled!",
    "I feel really down.",
    "This is tough for me.",
    "I'm just not myself today.",
    "It's just another day.",
    "I'm okay.",
    "It is what it is.",
    "This is frustrating!",
    "I'm really upset about this.",
    "I can't believe this happened!",
    "Couldn't be happier today!",
    "This just feels right.",
    "I love this!",
    "I'm heartbroken.",
    "Everything feels heavy.",
    "Wish things were different.",
    "Just going through the motions.",
    "I'm feeling indifferent.",
    "What did I do to deserve this?",
    "I'm at my wit's end!",
    "Overjoyed with this news!",
    "I'm on cloud nine!",
    "Feeling blessed and grateful.",
    "Life's full of ups and downs.",
    "Trying to stay positive.",
    "Everything's a bit overwhelming.",
    "I'm content with where I am.",
    "Finally, some peace and quiet.",
    "That was the last straw!",
    "They always let me down."
], columns= ['expression'])
sentiment_df['sentiment'] = ''

vader_df = sentiment_df.copy() #for Vader

sentiment_df
# Out:
#                           expression sentiment
# 0                   This is amazing!
# 1              I can't stop smiling!
# 2                   I'm so thrilled!
# 3                I feel really down.
# 4              This is tough for me.
# 5         I'm just not myself today.
# 6             It's just another day.
# 7                          I'm okay.
# 8                  It is what it is.
# 9               This is frustrating!
# 10      I'm really upset about this.
# 11    I can't believe this happened!
# 12        Couldn't be happier today!
# 13            This just feels right.
# 14                      I love this!
# 15                  I'm heartbroken.
# 16           Everything feels heavy.
# 17       Wish things were different.
# 18   Just going through the motions.
# 19          I'm feeling indifferent.
# 20    What did I do to deserve this?
# 21              I'm at my wit's end!
# 22         Overjoyed with this news!
# 23                I'm on cloud nine!
# 24     Feeling blessed and grateful.
# 25     Life's full of ups and downs.
# 26          Trying to stay positive.
# 27  Everything's a bit overwhelming.
# 28      I'm content with where I am.
# 29    Finally, some peace and quiet.
# 30          That was the last straw!
# 31          They always let me down.

# %%
act_prompt = ChatPromptTemplate.from_messages([
    ("system", """Classify the sentiment of the following expression as one of: "positive", "negative", or "neutral". Respond with only one word. :D"""),
    ("user", "{input}")
])

act_llm = ChatGroq(
    model_name="llama-3.3-70b-versatile",
    temperature=0.7
)

act_chain = act_prompt | act_llm | StrOutputParser()

def classify_sentiment(expression: str) -> str:
    try:
        response = act_llm.invoke([
            {"role": "system", "content": 'Classify the sentiment of the following expression as one of: "positive", "negative", or "neutral". Respond with only one word.'},
            {"role": "user", "content": expression}
        ])
        return response.content.strip().lower()
    except Exception as e:
        return "error"

sentiment_df['sentiment'] = sentiment_df['expression'].apply(classify_sentiment)

display(sentiment_df)
# Out:
#                           expression  sentiment
# 0                   This is amazing!   positive
# 1              I can't stop smiling!  positive.
# 2                   I'm so thrilled!   positive
# 3                I feel really down.  negative.
# 4              This is tough for me.  negative.
# 5         I'm just not myself today.  negative.
# 6             It's just another day.   neutral.
# 7                          I'm okay.   neutral.
# 8                  It is what it is.   neutral.
# 9               This is frustrating!  negative.
# 10      I'm really upset about this.  negative.
# 11    I can't believe this happened!  negative.
# 12        Couldn't be happier today!   positive
# 13            This just feels right.  positive.
# 14                      I love this!   positive
# 15                  I'm heartbroken.  negative.
# 16           Everything feels heavy.  negative.
# 17       Wish things were different.  negative.
# 18   Just going through the motions.  negative.
# 19          I'm feeling indifferent.   neutral.
# 20    What did I do to deserve this?  negative.
# 21              I'm at my wit's end!  negative.
# 22         Overjoyed with this news!   positive
# 23                I'm on cloud nine!  positive.
# 24     Feeling blessed and grateful.  positive.
# 25     Life's full of ups and downs.   neutral.
# 26          Trying to stay positive.  positive.
# 27  Everything's a bit overwhelming.  negative.
# 28      I'm content with where I am.  positive.
# 29    Finally, some peace and quiet.  positive.
# 30          That was the last straw!  negative.
# 31          They always let me down.  negative.

# %% [markdown]
# ## Using Vader (Valence Aware Dictionary and sEntiment Reasoner) Sentiment Analysis

# %%
sia = SentimentIntensityAnalyzer()

vader_df['scores'] = vader_df['expression'].apply(lambda expression: sia.polarity_scores(expression))
vader_df['compound'] = vader_df['scores'].apply(lambda score_dict: score_dict['compound']) #check for overall sentiment polarity of the expression
vader_df['sentiment'] = ['positive' if score > 0 
                                       else 'negative' if score < 0
                                       else 'neautral'
                                       for score in vader_df['compound']]

vader_df
# Out:
#                           expression sentiment  \
# 0                   This is amazing!  positive
# 1              I can't stop smiling!  negative
# 2                   I'm so thrilled!  positive
# 3                I feel really down.  neautral
# 4              This is tough for me.  negative
# 5         I'm just not myself today.  neautral
# 6             It's just another day.  neautral
# 7                          I'm okay.  positive
# 8                  It is what it is.  neautral
# 9               This is frustrating!  negative
# 10      I'm really upset about this.  negative
# 11    I can't believe this happened!  neautral
# 12        Couldn't be happier today!  negative
# 13            This just feels right.  neautral
# 14                      I love this!  positive
# 15                  I'm heartbroken.  negative
# 16           Everything feels heavy.  neautral
# 17       Wish things were different.  positive
# 18   Just going through the motions.  neautral
# 19          I'm feeling indifferent.  negative
# 20    What did I do to deserve this?  neautral
# 21              I'm at my wit's end!  neautral
# 22         Overjoyed with this news!  positive
# 23                I'm on cloud nine!  neautral
# 24     Feeling blessed and grateful.  positive
# 25     Life's full of ups and downs.  neautral
# 26          Trying to stay positive.  positive
# 27  Everything's a bit overwhelming.  neautral
# 28      I'm content with where I am.  neautral
# 29    Finally, some peace and quiet.  positive
# 30          That was the last straw!  neautral
# 31          They always let me down.  neautral
#
#                                                scores  compound
# 0   {'neg': 0.0, 'neu': 0.328, 'pos': 0.672, 'comp...    0.6239
# 1   {'neg': 0.49, 'neu': 0.177, 'pos': 0.334, 'com...   -0.2225
# 2   {'neg': 0.0, 'neu': 0.365, 'pos': 0.635, 'comp...    0.5400
# 3   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 4   {'neg': 0.273, 'neu': 0.727, 'pos': 0.0, 'comp...   -0.1280
# 5   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 6   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 7   {'neg': 0.0, 'neu': 0.345, 'pos': 0.655, 'comp...    0.2263
# 8   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 9   {'neg': 0.615, 'neu': 0.385, 'pos': 0.0, 'comp...   -0.4926
# 10  {'neg': 0.42, 'neu': 0.58, 'pos': 0.0, 'compou...   -0.4391
# 11  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 12  {'neg': 0.506, 'neu': 0.494, 'pos': 0.0, 'comp...   -0.4710
# 13  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 14  {'neg': 0.0, 'neu': 0.182, 'pos': 0.818, 'comp...    0.6696
# 15  {'neg': 0.811, 'neu': 0.189, 'pos': 0.0, 'comp...   -0.6486
# 16  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 17  {'neg': 0.0, 'neu': 0.526, 'pos': 0.474, 'comp...    0.4019
# 18  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 19  {'neg': 0.419, 'neu': 0.233, 'pos': 0.349, 'co...   -0.0772
# 20  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 21  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 22  {'neg': 0.0, 'neu': 0.429, 'pos': 0.571, 'comp...    0.6114
# 23  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 24  {'neg': 0.0, 'neu': 0.106, 'pos': 0.894, 'comp...    0.8126
# 25  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 26  {'neg': 0.0, 'neu': 0.455, 'pos': 0.545, 'comp...    0.5574
# 27  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 28  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 29  {'neg': 0.0, 'neu': 0.533, 'pos': 0.467, 'comp...    0.5423
# 30  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 31  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000

# %% [markdown]
# # Activity 2
# 🧠  Prompt Engineering Exercise: Structured Insight Extraction
# ### 📦 Scenario
# #### A teacher gives a riddle to her class:
#
# “If you take the number of letters in the English word for the smallest prime number, multiply that by the position of that prime in the list of primes, and then subtract the number of letters in the word for the next prime, what do you get?”
#
# What is the final result?
#
# ### 🎯 Objective
# #### Utilize CoT prompting technique to solve the riddle.

# %%
# Initialize Groq LLM
llm = ChatGroq(
    model_name="llama-3.3-70b-versatile",
    temperature=0.7
)

#setup the prompt
prompt = ChatPromptTemplate.from_messages([
    ("system", """
                You are an expert at solving riddles using step-by-step reasoning :D.
                Think step by step to extract the answer.
                Explain it like your explaining to a 5 years old :D.
                """),
    ("user", "{input}")
])


#define the chain
chain = prompt | llm | StrOutputParser()

#call the LLM
user_prompt = "If you take the number of letters in the English word for the smallest prime number,\
 multiply that by the position of that prime in the list of primes, and then subtract the number of letters in the word for the next prime, what do you get?"
result = chain.invoke({"input": user_prompt})
print(result)
# Out:
# Let's break it down step by step, like we're solving a fun puzzle.
#
# 1. **What's the smallest prime number?**
# The smallest prime number is 2.
#
# 2. **What's the English word for the smallest prime number?**
# The English word for 2 is "two".
#
# 3. **How many letters are in the word "two"?**
# Let's count them: T-W-O. There are 3 letters in the word "two".
#
# 4. **What's the position of 2 in the list of primes?**
# 2 is the first prime number, so its position is 1.
#
# 5. **Now, let's multiply the number of letters by the position:**
# We multiply 3 (the number of letters in "two") by 1 (the position of 2). 3 * 1 = 3.
#
# 6. **What's the next prime number after 2?**
# The next prime number is 3.
#
# 7. **What's the English word for the next prime number?**
# The English word for 3 is "three".
#
# 8. **How many letters are in the word "three"?**
# Let's count them: T-H-R-E-E. There are 5 letters in the word "three".
#
# 9. **Now, let's subtract the number of letters in "three" from our previous result:**
# We subtract 5 (the number of letters in "three") from 3. 3 - 5 = -2.
#
# So, the answer is -2. Isn't that a fun puzzle?

# %% [markdown]
# # Activity 3:
# 🧠 Prompt Engineering Exercise: Structured Insight Extraction
#
#
# 📦 Scenario
# You are given a small dataset of customer feedback in free-form text. Your task is to design a prompt that turns these messy text entries into structured information suitable for a spreadsheet or database.
#
# 🎯 Objective
# Craft a high-quality prompt that extracts structured insights from unstructured text data, focusing on clarity, structure, and consistency of output.
#
# Design a single prompt that takes the above list and returns a structured table with the following columns:
#
# | Feedback | Sentiment | Issues Mentioned | Actionable Suggestion |

# %% [markdown]
# 1. "Shipping was delayed but the product quality was excellent."
# 2. "The support team was unhelpful and I never got a response to my email."
# 3. "Loved the fast delivery. Great material. Will definitely buy again!"
# 4. "Not happy with the purchase. Item didn’t match the photo."
# 5. "Amazing experience! Great fit, quick delivery, and friendly customer service."
# 6. "The shirt fabric feels cheap. It shrank after one wash."
# 7. "Packaging was impressive. Arrived a day early!"
# 8. "Customer service ignored my refund request for a week."
# 9. "Website was confusing. Took me a while to find the size guide."
# 10. "Very satisfied. My third order and still great quality."
# 11. "The pants were too tight even though I followed the sizing chart."
# 12. "Got the wrong color. Asked for black, received navy blue."
# 13. "Product is good, but I wish the price was more affordable."
# 14. "Quick checkout and smooth delivery. Thanks!"
# 15. "Item had a weird smell out of the box. Needed to wash it first."

# %%
# Initialize Groq LLM
llm = ChatGroq(
    model_name="llama-3.3-70b-versatile",
    temperature=0.7
)

#setup the prompt
prompt = ChatPromptTemplate.from_messages([
    ("system", """
                You are a helpful assistant that extracts structured insights from messy or unstructured text feedback :D.

Your goal is to convert the following input into a table with these columns:

| feedback | Sentiment | Issues Mentioned | Actionable Suggestion |

- **Sentiment** should be one of: Positive, Negative, Neutral.
- **Issues Mentioned** should be a comma-separated list of problems or concerns found in the text (if any).
- **Actionable Suggestion** should be a specific recommendation for improvement, based on the feedback.
If no issues or suggestions are found, write 'None'.

                Return the output in clean markdown table format :D."""),
    ("user", "{input}")
])

#define the chain
chain = prompt | llm | StrOutputParser()

#call the LLM
user_prompt = "The support team was unhelpful and I never got a response to my email."
result = chain.invoke({"input": user_prompt})
print(result)
# Out:
# | feedback | Sentiment | Issues Mentioned | Actionable Suggestion |
# | --- | --- | --- | --- |
# | The support team was unhelpful and I never got a response to my email. | Negative | unhelpful support team, no response to email | Implement a more responsive and helpful support system, including timely email responses. |

# %%
query = {
"1.": "Shipping was delayed but the product quality was excellent.",
"2.": "The support team was unhelpful and I never got a response to my email.",
"3.": "Loved the fast delivery. Great material. Will definitely buy again!",
"4.": "Not happy with the purchase. Item didn’t match the photo.",
"5.": "Amazing experience! Great fit, quick delivery, and friendly customer service.",
"6.": "The shirt fabric feels cheap. It shrank after one wash.",
"7.": "Packaging was impressive. Arrived a day early!",
"8.": "Customer service ignored my refund request for a week.",
"9.": "Website was confusing. Took me a while to find the size guide.",
"10.": "Very satisfied. My third order and still great quality.",
"11.": "The pants were too tight even though I followed the sizing chart.",
"12.": "Got the wrong color. Asked for black, received navy blue.",
"13.": "Product is good, but I wish the price was more affordable.",
"14.": "Quick checkout and smooth delivery. Thanks!",
"15.": "Item had a weird smell out of the box. Needed to wash it first."
}

result1 = chain.invoke({"input": query})
print(result1)
# Out:
# | feedback | Sentiment | Issues Mentioned | Actionable Suggestion |
# | --- | --- | --- | --- |
# | Shipping was delayed but the product quality was excellent. | Neutral | delayed shipping | Improve shipping efficiency to match product quality |
# | The support team was unhelpful and I never got a response to my email. | Negative | unhelpful support team, no email response | Provide timely and helpful customer support through email |
# | Loved the fast delivery. Great material. Will definitely buy again! | Positive | None | Continue providing fast delivery and great material quality |
# | Not happy with the purchase. Item didn’t match the photo. | Negative | item doesn't match photo | Ensure product photos accurately represent the item |
# | Amazing experience! Great fit, quick delivery, and friendly customer service. | Positive | None | Maintain great fit, quick delivery, and friendly customer service |
# | The shirt fabric feels cheap. It shrank after one wash. | Negative | cheap fabric, shrinkage | Improve fabric quality to prevent shrinkage and cheap feel |
# | Packaging was impressive. Arrived a day early! | Positive | None | Continue providing impressive packaging and early delivery |
# | Customer service ignored my refund request for a week. | Negative | ignored refund request | Respond to customer refund requests in a timely manner |
# | Website was confusing. Took me a while to find the size guide. | Negative | confusing website, hard to find size guide | Simplify website navigation and make size guide easily accessible |
# | Very satisfied. My third order and still great quality. | Positive | None | Maintain great quality across all orders |
# | The pants were too tight even though I followed the sizing chart. | Negative | sizing chart inaccuracies | Review and improve sizing chart accuracy |
# | Got the wrong color. Asked for black, received navy blue. | Negative | wrong color | Implement a double-check system for order color accuracy |
# | Product is good, but I wish the price was more affordable. | Neutral | high price | Consider offering discounts or promotions to improve affordability |
# | Quick checkout and smooth delivery. Thanks! | Positive | None | Continue providing quick checkout and smooth delivery |
# | Item had a weird smell out of the box. Needed to wash it first. | Negative | weird smell | Improve quality control to prevent items with weird smells from being shipped |
